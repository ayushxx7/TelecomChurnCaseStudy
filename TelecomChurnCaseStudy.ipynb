# %% [markdown]
# # Telecom Churn Case Study
# #### Predicting High Value Customers who are at the risk of churning
# - Submitted by Ayush Mandowara and Sameer Soin

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading and Understanding the Data

# %%
df = pd.read_csv('telecom_churn_data.csv')

# %%
df.head()
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 1     7001865778        109             0.0             0.0             0.0
# 2     7001625959        109             0.0             0.0             0.0
# 3     7001204172        109             0.0             0.0             0.0
# 4     7000142493        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# 1            6/30/2014            7/31/2014            8/31/2014
# 2            6/30/2014            7/31/2014            8/31/2014
# 3            6/30/2014            7/31/2014            8/31/2014
# 4            6/30/2014            7/31/2014            8/31/2014
#
#   last_date_of_month_9   arpu_6  ...  sachet_3g_9  fb_user_6  fb_user_7  \
# ...

# %%
df.shape
# Out:
# (99999, 226)

# %%
df.iloc[:, 0:5].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mobile_number   99999 non-null  int64
#  1   circle_id       99999 non-null  int64
#  2   loc_og_t2o_mou  98981 non-null  float64
#  3   std_og_t2o_mou  98981 non-null  float64
#  4   loc_ic_t2o_mou  98981 non-null  float64
# dtypes: float64(3), int64(2)
# memory usage: 3.8 MB

# %%
df.isnull().sum()
# Out:
# mobile_number        0
# circle_id            0
# loc_og_t2o_mou    1018
# std_og_t2o_mou    1018
# loc_ic_t2o_mou    1018
#                   ...
# aon                  0
# aug_vbc_3g           0
# jul_vbc_3g           0
# jun_vbc_3g           0
# sep_vbc_3g           0
# Length: 226, dtype: int64

# %%
df.describe()
# Out:
#        mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  \
# count   9.999900e+04    99999.0         98981.0         98981.0
# mean    7.001207e+09      109.0             0.0             0.0
# std     6.956694e+05        0.0             0.0             0.0
# min     7.000000e+09      109.0             0.0             0.0
# 25%     7.000606e+09      109.0             0.0             0.0
# 50%     7.001205e+09      109.0             0.0             0.0
# 75%     7.001812e+09      109.0             0.0             0.0
# max     7.002411e+09      109.0             0.0             0.0
#
#        loc_ic_t2o_mou        arpu_6        arpu_7        arpu_8        arpu_9  \
# count         98981.0  99999.000000  99999.000000  99999.000000  99999.000000
# mean              0.0    282.987358    278.536648    279.154731    261.645069
# std               0.0    328.439770    338.156291    344.474791    341.998630
# ...

# %%
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
df.describe()
# Out:
#        mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  \
# count   9.999900e+04    99999.0         98981.0         98981.0
# mean    7.001207e+09      109.0             0.0             0.0
# std     6.956694e+05        0.0             0.0             0.0
# min     7.000000e+09      109.0             0.0             0.0
# 25%     7.000606e+09      109.0             0.0             0.0
# 50%     7.001205e+09      109.0             0.0             0.0
# 75%     7.001812e+09      109.0             0.0             0.0
# max     7.002411e+09      109.0             0.0             0.0
#
#        loc_ic_t2o_mou        arpu_6        arpu_7        arpu_8        arpu_9  \
# count         98981.0  99999.000000  99999.000000  99999.000000  99999.000000
# mean              0.0    282.987358    278.536648    279.154731    261.645069
# std               0.0    328.439770    338.156291    344.474791    341.998630
# ...

# %% [markdown]
# #### Checking duplicates

# %%
duplicate = df[df.duplicated(keep = 'last')]

duplicate.shape
# Out:
# (0, 226)

# %% [markdown]
# ##### Observation: There are no duplicate rows in the dataframe

# %% [markdown]
# #### Checking columns which have only one unique value

# %%
for col in df.columns:
    if len(df[col].unique()) == 1:
        print(col)
# Out:
# circle_id
# last_date_of_month_6

# %% [markdown]
# #### Checking count of numeric and object columns

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.to_list()

# %%
len(numeric_cols)
# Out:
# 177

# %%
len(df.select_dtypes('object').columns.to_list())
# Out:
# 0

# %%
all_columns = df.columns.to_list()

# %% [markdown]
# ---

# %% [markdown]
# ### Filtering High Value Customers

# %% [markdown]
# ##### Checking all columns which contain the string "rech" (short for recharge)

# %%
for i in all_columns:
    if 'rec' in i:
        print(i)
# Out:
# total_rech_num_6
# total_rech_num_7
# total_rech_num_8
# total_rech_amt_6
# total_rech_amt_7
# total_rech_amt_8
# max_rech_amt_6
# max_rech_amt_7
# max_rech_amt_8
# date_of_last_rech_6
# date_of_last_rech_7
# date_of_last_rech_8
# date_of_last_rech_data_6
# date_of_last_rech_data_7
# date_of_last_rech_data_8
# total_rech_data_6
# total_rech_data_7
# total_rech_data_8
# max_rech_data_6
# max_rech_data_7
# max_rech_data_8
# count_rech_2g_6
# count_rech_2g_7
# count_rech_2g_8
# count_rech_3g_6
# count_rech_3g_7
# count_rech_3g_8
# av_rech_amt_data_6
# av_rech_amt_data_7
# av_rech_amt_data_8
# num_days_last_recharge_calls_6
# num_days_last_recharge_calls_7
# num_days_last_recharge_calls_8
# num_days_last_recharge_data_6
# num_days_last_recharge_data_7
# num_days_last_recharge_data_8

# %%
df[df['total_rech_data_6'] > 1][['total_rech_num_6', 'total_rech_amt_6', 'max_rech_amt_6', 'date_of_last_rech_6', 'total_rech_data_6', 'max_rech_data_6', 'av_rech_amt_data_6']]
# Out:
#        total_rech_num_6  total_rech_amt_6  max_rech_amt_6 date_of_last_rech_6  \
# 33                    7              1058             252          2014-06-30
# 53                   24              1159             120          2014-06-29
# 56                   12               528             154          2014-06-28
# 57                   10              1389             655          2014-06-29
# 61                   15               621             154          2014-06-28
# ...                 ...               ...             ...                 ...
# 99923                 8              1096             252          2014-06-28
# 99947                 7               118              98          2014-06-23
# 99955                 9               127              50          2014-06-25
# 99957                17              1376             154          2014-06-30
# 99997                 3               381             202          2014-06-17
#
# ...

# %% [markdown]
# ##### After carefully analyzing the data, it was found that the missing values for the columns represented that no recharge was done during that period. Hence, we will be filling those values with 0.

# %%
df[['av_rech_amt_data_6', 'total_rech_data_6',
   'av_rech_amt_data_7', 'total_rech_data_7',
   'av_rech_amt_data_8', 'total_rech_data_8',
   'av_rech_amt_data_9', 'total_rech_data_9',
   'total_rech_amt_6', 'total_rech_amt_7',
    'total_rech_amt_8', 'total_rech_amt_9'
   ]] = df[['av_rech_amt_data_6', 'total_rech_data_6',
   'av_rech_amt_data_7', 'total_rech_data_7',
   'av_rech_amt_data_8', 'total_rech_data_8',
   'av_rech_amt_data_9', 'total_rech_data_9',
   'total_rech_amt_6', 'total_rech_amt_7',
    'total_rech_amt_8', 'total_rech_amt_9'
   ]].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-3f98cb2b4f8e> in <module>
#       5    'total_rech_amt_6', 'total_rech_amt_7',
#       6     'total_rech_amt_8', 'total_rech_amt_9'
# ----> 7    ]] = df[['av_rech_amt_data_6', 'total_rech_data_6',
#       8    'av_rech_amt_data_7', 'total_rech_data_7',
#       9    'av_rech_amt_data_8', 'total_rech_data_8',
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
# ...

# %% [markdown]
# ##### Calculating total amount spent on data recharges for each month

# %%
df['total_spend_data_6'] = df['av_rech_amt_data_6']*df['total_rech_data_6']
df['total_spend_data_7'] = df['av_rech_amt_data_7']*df['total_rech_data_7']
df['total_spend_data_8'] = df['av_rech_amt_data_8']*df['total_rech_data_8']
df['total_spend_data_9'] = df['av_rech_amt_data_9']*df['total_rech_data_9']

# %% [markdown]
# ##### Calculating total amount spent (data + calls) for each month

# %%
df['total_spend_calls_plus_data_6'] = df['total_spend_data_6']+df['total_rech_amt_6']
df['total_spend_calls_plus_data_7'] = df['total_spend_data_7']+df['total_rech_amt_7']
df['total_spend_calls_plus_data_8'] = df['total_spend_data_8']+df['total_rech_amt_8']
df['total_spend_calls_plus_data_9'] = df['total_spend_data_9']+df['total_rech_data_9']

# %%
df['total_spend_calls_plus_data_6']
# Out:
# 0         614.0
# 1          74.0
# 2         168.0
# 3         230.0
# 4         252.0
#           ...
# 99994      60.0
# 99995     110.0
# 99996     197.0
# 99997    2130.0
# 99998     864.0
# Name: total_spend_calls_plus_data_6, Length: 99999, dtype: float64

# %% [markdown]
# ##### As per business understanding,
# - we know the months 6 and 7 are good phase months.
# - Further, we have to take average of these two months and filter data to keep the top 70% consumers only.

# %%
df['total_spend_amt_good_phase'] = (df['total_spend_calls_plus_data_6']+df['total_spend_calls_plus_data_7'])/2

# %%
df[['total_spend_calls_plus_data_6', 'total_spend_calls_plus_data_7', 'total_spend_amt_good_phase']].head()
# Out:
#    total_spend_calls_plus_data_6  total_spend_calls_plus_data_7  \
# 0                          614.0                          504.0
# 1                           74.0                          538.0
# 2                          168.0                          315.0
# 3                          230.0                          310.0
# 4                          252.0                          350.0
#
#    total_spend_amt_good_phase
# 0                       559.0
# 1                       306.0
# 2                       241.5
# 3                       270.0
# 4                       301.0

# %% [markdown]
# ##### selecting high value customers based on business definition

# %%
df['total_spend_amt_good_phase'].quantile(0.7)
# Out:
# 478.0

# %%
df[df['total_spend_amt_good_phase'] > df['total_spend_amt_good_phase'].quantile(0.7)].shape
# Out:
# (29953, 235)

# %%
df = df[df['total_spend_amt_good_phase'] > df['total_spend_amt_good_phase'].quantile(0.7)]

# %%
df.shape
# Out:
# (29953, 235)

# %% [markdown]
# ##### Observation
# - 70th quantile average recharge amount for the good phase is rs 478

# %% [markdown]
# ---

# %% [markdown]
# ### Labelling Churn
# - As per business understanding, if a customer has not used any data or calling services in month of september, then we will identify him as churn (1) else not churn (0)

# %%
df['total_usage_9'] = df['total_ic_mou_9']+df['total_og_mou_9']+df['vol_2g_mb_9']+df['vol_3g_mb_9']

# %%
df['churn'] = (df['total_usage_9']>0).map({True: 1, False: 0})

# %%
df.head()
# Out:
#     mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0      7000842753        109             0.0             0.0             0.0
# 7      7000701601        109             0.0             0.0             0.0
# 8      7001524846        109             0.0             0.0             0.0
# 21     7002124215        109             0.0             0.0             0.0
# 23     7000887461        109             0.0             0.0             0.0
#
#    last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0             6/30/2014            7/31/2014            8/31/2014
# 7             6/30/2014            7/31/2014            8/31/2014
# 8             6/30/2014            7/31/2014            8/31/2014
# 21            6/30/2014            7/31/2014            8/31/2014
# 23            6/30/2014            7/31/2014            8/31/2014
#
#    last_date_of_month_9    arpu_6    arpu_7    arpu_8   arpu_9  onnet_mou_6  \
# ...

# %% [markdown]
# ##### Dropping Data for Month 9

# %%
all_columns = df.columns.to_list()

# %%
cols_to_drop = []
for i in all_columns:
    if "_9" in i:
#         print(f'dropping {i}')
        cols_to_drop.append(i)

# %%
df.drop(cols_to_drop, axis=1, inplace=True)

# %%
df.head()
# Out:
#     mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0      7000842753        109             0.0             0.0             0.0
# 7      7000701601        109             0.0             0.0             0.0
# 8      7001524846        109             0.0             0.0             0.0
# 21     7002124215        109             0.0             0.0             0.0
# 23     7000887461        109             0.0             0.0             0.0
#
#    last_date_of_month_6 last_date_of_month_7 last_date_of_month_8    arpu_6  \
# 0             6/30/2014            7/31/2014            8/31/2014   197.385
# 7             6/30/2014            7/31/2014            8/31/2014  1069.180
# 8             6/30/2014            7/31/2014            8/31/2014   378.721
# 21            6/30/2014            7/31/2014            8/31/2014   514.453
# 23            6/30/2014            7/31/2014            8/31/2014    74.350
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### Understanding object columns

# %%
object_cols = df.select_dtypes('object')

# %%
object_cols
# Out:
#       last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0                6/30/2014            7/31/2014            8/31/2014
# 7                6/30/2014            7/31/2014            8/31/2014
# 8                6/30/2014            7/31/2014            8/31/2014
# 21               6/30/2014            7/31/2014            8/31/2014
# 23               6/30/2014            7/31/2014            8/31/2014
# ...                    ...                  ...                  ...
# 99981            6/30/2014            7/31/2014            8/31/2014
# 99984            6/30/2014            7/31/2014            8/31/2014
# 99986            6/30/2014            7/31/2014            8/31/2014
# 99988            6/30/2014            7/31/2014            8/31/2014
# 99997            6/30/2014            7/31/2014            8/31/2014
#
#       date_of_last_rech_6 date_of_last_rech_7 date_of_last_rech_8  \
# 0               6/21/2014           7/16/2014            8/8/2014
# ...

# %% [markdown]
# ##### Observation: All object columns are date

# %%
df.iloc[7:8]
# Out:
#     mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 41     7000721289        109             0.0             0.0             0.0
#
#    last_date_of_month_6 last_date_of_month_7 last_date_of_month_8   arpu_6  \
# 41            6/30/2014            7/31/2014            8/31/2014  482.832
#
#      arpu_7   arpu_8  onnet_mou_6  onnet_mou_7  onnet_mou_8  offnet_mou_6  \
# 41  425.764  229.769        86.39       118.88        80.44        232.36
#
#     offnet_mou_7  offnet_mou_8  roam_ic_mou_6  roam_ic_mou_7  roam_ic_mou_8  \
# 41        280.78        136.69            0.0            0.0            0.0
#
#     roam_og_mou_6  roam_og_mou_7  roam_og_mou_8  loc_og_t2t_mou_6  \
# 41            0.0            0.0            0.0             86.39
#
#     loc_og_t2t_mou_7  loc_og_t2t_mou_8  loc_og_t2m_mou_6  loc_og_t2m_mou_7  \
# 41            118.88             80.44            142.69            174.91
#
# ...

# %% [markdown]
# ##### Converting all object columns to datetime for further analysis

# %%
df['date_of_last_rech_data_6'].apply(pd.to_datetime, errors='coerce')
# Out:
# 0       2014-06-21
# 7              NaT
# 8              NaT
# 21             NaT
# 23             NaT
#            ...
# 99981   2014-06-17
# 99984   2014-06-15
# 99986   2014-06-17
# 99988          NaT
# 99997   2014-06-17
# Name: date_of_last_rech_data_6, Length: 29953, dtype: datetime64[ns]

# %%
for i in object_cols:
    print(f'running on {i}')
    df[i] = df[i].apply(pd.to_datetime, errors='coerce')
# Out:
# running on last_date_of_month_6
# running on last_date_of_month_7
# running on last_date_of_month_8
# running on date_of_last_rech_6
# running on date_of_last_rech_7
# running on date_of_last_rech_8
# running on date_of_last_rech_data_6
# running on date_of_last_rech_data_7
# running on date_of_last_rech_data_8

# %% [markdown]
# ##### Calculating number of days since last recharge

# %%
df['num_days_last_recharge_calls_6'] = df['last_date_of_month_6'] - df['date_of_last_rech_6']
df['num_days_last_recharge_calls_7'] = df['last_date_of_month_7'] - df['date_of_last_rech_7']
df['num_days_last_recharge_calls_8'] = df['last_date_of_month_8'] - df['date_of_last_rech_8']

df['num_days_last_recharge_data_6'] = df['last_date_of_month_6'] - df['date_of_last_rech_data_6']
df['num_days_last_recharge_data_7'] = df['last_date_of_month_7'] - df['date_of_last_rech_data_7']
df['num_days_last_recharge_data_8'] = df['last_date_of_month_8'] - df['date_of_last_rech_data_8']

# %%
df.head(5)
# Out:
#     mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0      7000842753        109             0.0             0.0             0.0
# 7      7000701601        109             0.0             0.0             0.0
# 8      7001524846        109             0.0             0.0             0.0
# 21     7002124215        109             0.0             0.0             0.0
# 23     7000887461        109             0.0             0.0             0.0
#
#    last_date_of_month_6 last_date_of_month_7 last_date_of_month_8    arpu_6  \
# 0            2014-06-30           2014-07-31           2014-08-31   197.385
# 7            2014-06-30           2014-07-31           2014-08-31  1069.180
# 8            2014-06-30           2014-07-31           2014-08-31   378.721
# 21           2014-06-30           2014-07-31           2014-08-31   514.453
# 23           2014-06-30           2014-07-31           2014-08-31    74.350
#
# ...

# %%
num_days_cols = ['num_days_last_recharge_calls_6', 'num_days_last_recharge_calls_7', 'num_days_last_recharge_calls_8', 'num_days_last_recharge_data_6', 'num_days_last_recharge_data_7', 'num_days_last_recharge_data_8']

# %%
for i in num_days_cols:
    df[i] = df[i].dt.days

# %%
df.head(2)
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 7     7000701601        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8    arpu_6  \
# 0           2014-06-30           2014-07-31           2014-08-31   197.385
# 7           2014-06-30           2014-07-31           2014-08-31  1069.180
#
#      arpu_7    arpu_8  onnet_mou_6  onnet_mou_7  onnet_mou_8  offnet_mou_6  \
# 0   214.816   213.803          NaN          NaN         0.00           NaN
# 7  1349.850  3171.480        57.84        54.68        52.29        453.43
#
#    offnet_mou_7  offnet_mou_8  roam_ic_mou_6  roam_ic_mou_7  roam_ic_mou_8  \
# 0           NaN          0.00            NaN            NaN           0.00
# 7        567.16        325.91          16.23          33.49          31.64
#
# ...

# %%
df[num_days_cols] = df[num_days_cols].fillna(-1)

# %%
df.head(3)
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 7     7000701601        109             0.0             0.0             0.0
# 8     7001524846        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8    arpu_6  \
# 0           2014-06-30           2014-07-31           2014-08-31   197.385
# 7           2014-06-30           2014-07-31           2014-08-31  1069.180
# 8           2014-06-30           2014-07-31           2014-08-31   378.721
#
#      arpu_7    arpu_8  onnet_mou_6  onnet_mou_7  onnet_mou_8  offnet_mou_6  \
# 0   214.816   213.803          NaN          NaN         0.00           NaN
# 7  1349.850  3171.480        57.84        54.68        52.29        453.43
# 8   492.223   137.362       413.69       351.03        35.08         94.66
#
# ...
